# %%
import numpy as np
import altair as alt
import pandas as pd
import math

# %%
x = np.logspace(1+math.log10(2), 2+math.log10(2), 100)

# %%
y1 = [xi for xi in x]
y2 = [xi-math.sqrt(xi) for xi in x]

# %%
df = pd.DataFrame({'x': x, 'y1': y1, 'y2': y2})

# %%
df
# Out:
#              x          y1          y2
# 0    20.000000   20.000000   15.527864
# 1    20.470620   20.470620   15.946173
# 2    20.952315   20.952315   16.374945
# 3    21.445344   21.445344   16.814433
# 4    21.949975   21.949975   17.264895
# ..         ...         ...         ...
# 95  182.232551  182.232551  168.733197
# 96  186.520669  186.520669  172.863412
# 97  190.909691  190.909691  177.092684
# 98  195.401991  195.401991  181.423365
# 99  200.000000  200.000000  185.857864
#
# [100 rows x 3 columns]

# %%
g1 = alt.Chart(df).mark_line().encode(x='x', 
                                      y=alt.Y('y1', scale=alt.Scale(type='log', base=10, nice=False)))
g2 = alt.Chart(df).mark_line().encode(
    x='x', 
    y=alt.Y('y2', 
            scale=alt.Scale(type='log', base=10, nice=False),
            axis=alt.Axis(grid=True, title='ouhoua', titleAnchor='middle', tickCount=5, labelExpr='datum.value > 50 ? null : datum.label')))

# %%
l = alt.layer(g1, g2)
l  | l.resolve_scale(y='independent')
# Out:
# alt.HConcatChart(...)
